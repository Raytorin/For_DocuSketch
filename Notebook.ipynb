# %%
from main import DrawingPlots
from IPython.display import Image, display

# %%
ty = DrawingPlots

# %%
data_folder_json = 'deviation.json'
plots = ty.draw_plots(ty, data_folder_json, 30)[0]

# %%
for plot_path in plots:
    display(Image(filename=f'{plot_path}'))
